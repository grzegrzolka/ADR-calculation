# %%
import pandas as pd

# %%
file_name = "D-Value_A1_A2_Exempt.xlsm"

# %%
df = pd.read_excel(file_name, sheet_name = "D-Value_A1_A2_Exempted")

# %%
df.head()
# Out:
#   Radionuclide D-Value [TBq] D1-Value (encapsulated) [TBq]  \
# 0       Ac-225          0.09                           0.3
# 1       Ac-227          0.04                           0.2
# 2       Ac-228          0.03                          0.03
# 3       Ag-105           0.1                           0.1
# 4      Ag-108m          0.04                          0.04
#
#   D2-Value (dispersed) [TBq] A1 [TBq] A2 [TBq]  \
# 0                       0.09      0.8    0.006
# 1                       0.04      0.9  0.00009
# 2                        100      0.6      0.5
# 3                        100        2        2
# 4                         20      0.7      0.7
#
#   Transport Security Threshold [TBq] Unnamed: 7  \
# 0                                 18   3 000*A2
# 1                               0.27   3 000*A2
# 2                               1500   3 000*A2
# 3                               6000   3 000*A2
# 4                               2100   3 000*A2
#
#   High Activity Source Directive 2013/59/EURATOM  [TBq] D-Value [Bq] P2  \
# 0                                               0.09        90000000000
# 1                                               0.04        40000000000
# 2                                               0.03        30000000000
# 3                                                0.1       100000000000
# 4                                               0.04        40000000000
#
#   D1-Value (encapsulated) [Bq] D2-Value (dispersed) [Bq]        A1 [Bq]  \
# 0                 300000000000               90000000000   800000000000
# 1                 200000000000               40000000000   900000000000
# 2                  30000000000           100000000000000   600000000000
# 3                 100000000000           100000000000000  2000000000000
# 4                  40000000000            20000000000000   700000000000
#
#          A2 [Bq] Transport Security Threshold [Bq]  \
# 0     6000000000                    18000000000000
# 1       90000000               270000000000.000031
# 2   500000000000                  1500000000000000
# 3  2000000000000                  6000000000000000
# 4   700000000000                  2100000000000000
#
#   High Activity Source Directive 2013/59/EURATOM  [Bq]  \
# 0                                        90000000000
# 1                                        40000000000
# 2                                        30000000000
# 3                                       100000000000
# 4                                        40000000000
#
#    Activity concentration for exempt material (Bq/g)  \
# 0                                               10.0
# 1                                                0.1
# 2                                               10.0
# 3                                              100.0
# 4                                               10.0
#
#    Activity limit for an exempt consignment (Bq) P1  Desintegration [Years]
# 0                                             10000                0.027379
# 1                                              1000                     NaN
# 2                                           1000000                0.000719
# 3                                           1000000                     NaN
# 4                                           1000000                     NaN

# %%
df.columns
# Out:
# Index(['Radionuclide', 'D-Value [TBq]', 'D1-Value (encapsulated) [TBq]',
#        'D2-Value (dispersed) [TBq]', 'A1 [TBq]', 'A2 [TBq]',
#        'Transport Security Threshold [TBq]', 'Unnamed: 7',
#        'High Activity Source Directive 2013/59/EURATOM  [TBq]',
#        'D-Value [Bq] P2', 'D1-Value (encapsulated) [Bq]',
#        'D2-Value (dispersed) [Bq]', 'A1 [Bq]', 'A2 [Bq]',
#        'Transport Security Threshold [Bq]',
#        'High Activity Source Directive 2013/59/EURATOM  [Bq]',
#        'Activity concentration for exempt material (Bq/g)',
#        'Activity limit for an exempt consignment (Bq) P1',
#        'Desintegration [Years]'],
#       dtype='object')

# %%
working_df = df[["Radionuclide", 
                "D-Value [TBq]", 
                "A1 [TBq]", 
                "A2 [TBq]", 
                "Transport Security Threshold [TBq]",
                "High Activity Source Directive 2013/59/EURATOM  [TBq]",
                "D-Value [Bq] P2",
                "Activity concentration for exempt material (Bq/g)",
                "Activity limit for an exempt consignment (Bq) P1",
                "Desintegration [Years]"]]
working_df
# Out:
#     Radionuclide D-Value [TBq] A1 [TBq] A2 [TBq]  \
# 0         Ac-225          0.09      0.8    0.006
# 1         Ac-227          0.04      0.9  0.00009
# 2         Ac-228          0.03      0.6      0.5
# 3         Ag-105           0.1        2        2
# 4        Ag-108m          0.04      0.7      0.7
# ..           ...           ...      ...      ...
# 372       Zn-69m           0.2        3      0.6
# 373        Zr-88          0.02        3        3
# 374        Zr-93            UL       UL       UL
# 375        Zr-95          0.04        2      0.8
# 376        Zr-97          0.04      0.4      0.4
#
#     Transport Security Threshold [TBq]  \
# 0                                   18
# 1                                 0.27
# 2                                 1500
# 3                                 6000
# 4                                 2100
# ..                                 ...
# 372                               1800
# 373                               9000
# 374                                 UL
# 375                               2400
# 376                               1200
#
#     High Activity Source Directive 2013/59/EURATOM  [TBq] D-Value [Bq] P2  \
# 0                                                 0.09        90000000000
# 1                                                 0.04        40000000000
# 2                                                 0.03        30000000000
# 3                                                  0.1       100000000000
# 4                                                 0.04        40000000000
# ..                                                 ...                ...
# 372                                                0.2       200000000000
# 373                                               0.02        20000000000
# 374                                                 UL                 UL
# 375                                               0.04        40000000000
# 376                                               0.04        40000000000
#
#      Activity concentration for exempt material (Bq/g)  \
# 0                                                 10.0
# 1                                                  0.1
# 2                                                 10.0
# 3                                                100.0
# 4                                                 10.0
# ..                                                 ...
# 372                                              100.0
# 373                                              100.0
# 374                                             1000.0
# 375                                               10.0
# 376                                               10.0
#
#      Activity limit for an exempt consignment (Bq) P1  Desintegration [Years]
# 0                                               10000                0.027379
# 1                                                1000                     NaN
# 2                                             1000000                0.000719
# 3                                             1000000                     NaN
# 4                                             1000000                     NaN
# ..                                                ...                     ...
# 372                                           1000000                     NaN
# 373                                           1000000                     NaN
# 374                                          10000000                     NaN
# 375                                           1000000                0.175222
# 376                                            100000                     NaN
#
# [377 rows x 10 columns]

# %%
isotope_1 = "Cs-137"
activity_1 = 200

isotope_2 = "Am-241"
activity_2 = 1000

isotope_3 = "Sr-90"
activity_3 = 900

activity_list = [activity_1, activity_2, activity_3 ]

# %%
working_df = working_df.set_index("Radionuclide")
working_df
# Out:
#              D-Value [TBq] A1 [TBq] A2 [TBq]  \
# Radionuclide
# Ac-225                0.09      0.8    0.006
# Ac-227                0.04      0.9  0.00009
# Ac-228                0.03      0.6      0.5
# Ag-105                 0.1        2        2
# Ag-108m               0.04      0.7      0.7
# ...                    ...      ...      ...
# Zn-69m                 0.2        3      0.6
# Zr-88                 0.02        3        3
# Zr-93                   UL       UL       UL
# Zr-95                 0.04        2      0.8
# Zr-97                 0.04      0.4      0.4
#
#              Transport Security Threshold [TBq]  \
# Radionuclide
# Ac-225                                       18
# Ac-227                                     0.27
# Ac-228                                     1500
# Ag-105                                     6000
# Ag-108m                                    2100
# ...                                         ...
# Zn-69m                                     1800
# Zr-88                                      9000
# Zr-93                                        UL
# Zr-95                                      2400
# Zr-97                                      1200
#
#              High Activity Source Directive 2013/59/EURATOM  [TBq]  \
# Radionuclide
# Ac-225                                                     0.09
# Ac-227                                                     0.04
# Ac-228                                                     0.03
# Ag-105                                                      0.1
# Ag-108m                                                    0.04
# ...                                                         ...
# Zn-69m                                                      0.2
# Zr-88                                                      0.02
# Zr-93                                                        UL
# Zr-95                                                      0.04
# Zr-97                                                      0.04
#
#              D-Value [Bq] P2  \
# Radionuclide
# Ac-225           90000000000
# Ac-227           40000000000
# Ac-228           30000000000
# Ag-105          100000000000
# Ag-108m          40000000000
# ...                      ...
# Zn-69m          200000000000
# Zr-88            20000000000
# Zr-93                     UL
# Zr-95            40000000000
# Zr-97            40000000000
#
#               Activity concentration for exempt material (Bq/g)  \
# Radionuclide
# Ac-225                                                     10.0
# Ac-227                                                      0.1
# Ac-228                                                     10.0
# Ag-105                                                    100.0
# Ag-108m                                                    10.0
# ...                                                         ...
# Zn-69m                                                    100.0
# Zr-88                                                     100.0
# Zr-93                                                    1000.0
# Zr-95                                                      10.0
# Zr-97                                                      10.0
#
#               Activity limit for an exempt consignment (Bq) P1  \
# Radionuclide
# Ac-225                                                   10000
# Ac-227                                                    1000
# Ac-228                                                 1000000
# Ag-105                                                 1000000
# Ag-108m                                                1000000
# ...                                                        ...
# Zn-69m                                                 1000000
# Zr-88                                                  1000000
# Zr-93                                                 10000000
# Zr-95                                                  1000000
# Zr-97                                                   100000
#
#               Desintegration [Years]
# Radionuclide
# Ac-225                      0.027379
# Ac-227                           NaN
# Ac-228                      0.000719
# Ag-105                           NaN
# Ag-108m                          NaN
# ...                              ...
# Zn-69m                           NaN
# Zr-88                            NaN
# Zr-93                            NaN
# Zr-95                       0.175222
# Zr-97                            NaN
#
# [377 rows x 9 columns]

# %%
selected_isotopes = working_df.loc[[isotope_1, isotope_2, isotope_3]]

# %%
selected_isotopes ["Activity"] = activity_list 
selected_isotopes
# Out:
#              D-Value [TBq] A1 [TBq] A2 [TBq]  \
# Radionuclide
# Cs-137                 0.1        2      0.6
# Am-241                0.06       10    0.001
# Sr-90                    1      0.3      0.3
#
#              Transport Security Threshold [TBq]  \
# Radionuclide
# Cs-137                                        1
# Am-241                                      0.6
# Sr-90                                        10
#
#              High Activity Source Directive 2013/59/EURATOM  [TBq]  \
# Radionuclide
# Cs-137                                                      0.1
# Am-241                                                     0.06
# Sr-90                                                         1
#
#              D-Value [Bq] P2  \
# Radionuclide
# Cs-137          100000000000
# Am-241           60000000000
# Sr-90          1000000000000
#
#               Activity concentration for exempt material (Bq/g)  \
# Radionuclide
# Cs-137                                                     10.0
# Am-241                                                      1.0
# Sr-90                                                     100.0
#
#               Activity limit for an exempt consignment (Bq) P1  \
# Radionuclide
# Cs-137                                                   10000
# Am-241                                                   10000
# Sr-90                                                    10000
#
#               Desintegration [Years]  Activity
# Radionuclide
# Cs-137                         30.16       200
# Am-241                        432.00      1000
# Sr-90                          29.10       900

# %%
selected_isotopes ["Activity"].sum()
# Out:
# np.int64(2100)

# %%
selected_isotopes ["Isotope Activity Ratio"] = selected_isotopes ["Activity"] /selected_isotopes ["Activity"].sum()
selected_isotopes
# Out:
#              D-Value [TBq] A1 [TBq] A2 [TBq]  \
# Radionuclide
# Cs-137                 0.1        2      0.6
# Am-241                0.06       10    0.001
# Sr-90                    1      0.3      0.3
#
#              Transport Security Threshold [TBq]  \
# Radionuclide
# Cs-137                                        1
# Am-241                                      0.6
# Sr-90                                        10
#
#              High Activity Source Directive 2013/59/EURATOM  [TBq]  \
# Radionuclide
# Cs-137                                                      0.1
# Am-241                                                     0.06
# Sr-90                                                         1
#
#              D-Value [Bq] P2  \
# Radionuclide
# Cs-137          100000000000
# Am-241           60000000000
# Sr-90          1000000000000
#
#               Activity concentration for exempt material (Bq/g)  \
# Radionuclide
# Cs-137                                                     10.0
# Am-241                                                      1.0
# Sr-90                                                     100.0
#
#               Activity limit for an exempt consignment (Bq) P1  \
# Radionuclide
# Cs-137                                                   10000
# Am-241                                                   10000
# Sr-90                                                    10000
#
#               Desintegration [Years]  Activity  Isotope Activity Ratio
# Radionuclide
# Cs-137                         30.16       200                0.095238
# Am-241                        432.00      1000                0.476190
# Sr-90                          29.10       900                0.428571
