# %% [markdown]
# # Import libraries

# %%
import pandas as pd

# %% [markdown]
# # Import excel file and load to pandas dataframe

# %%
file_name = "D-Value_A1_A2_Exempt.xlsm"
df = pd.read_excel(file_name, sheet_name = "D-Value_A1_A2_Exempted")
df = df.set_index("Radionuclide")
df.head()
# Out:
#              D-Value [TBq] D1-Value (encapsulated) [TBq]  \
# Radionuclide
# Ac-225                0.09                           0.3
# Ac-227                0.04                           0.2
# Ac-228                0.03                          0.03
# Ag-105                 0.1                           0.1
# Ag-108m               0.04                          0.04
#
#              D2-Value (dispersed) [TBq] A1 [TBq] A2 [TBq]  \
# Radionuclide
# Ac-225                             0.09      0.8    0.006
# Ac-227                             0.04      0.9  0.00009
# Ac-228                              100      0.6      0.5
# Ag-105                              100        2        2
# Ag-108m                              20      0.7      0.7
#
#              Transport Security Threshold [TBq] Unnamed: 7  \
# Radionuclide
# Ac-225                                       18   3 000*A2
# Ac-227                                     0.27   3 000*A2
# Ac-228                                     1500   3 000*A2
# Ag-105                                     6000   3 000*A2
# Ag-108m                                    2100   3 000*A2
#
#              High Activity Source Directive 2013/59/EURATOM  [TBq]  \
# Radionuclide
# Ac-225                                                     0.09
# Ac-227                                                     0.04
# Ac-228                                                     0.03
# Ag-105                                                      0.1
# Ag-108m                                                    0.04
#
#              D-Value [Bq] P2 D1-Value (encapsulated) [Bq]  \
# Radionuclide
# Ac-225           90000000000                 300000000000
# Ac-227           40000000000                 200000000000
# Ac-228           30000000000                  30000000000
# Ag-105          100000000000                 100000000000
# Ag-108m          40000000000                  40000000000
#
#              D2-Value (dispersed) [Bq]        A1 [Bq]        A2 [Bq]  \
# Radionuclide
# Ac-225                     90000000000   800000000000     6000000000
# Ac-227                     40000000000   900000000000       90000000
# Ac-228                 100000000000000   600000000000   500000000000
# Ag-105                 100000000000000  2000000000000  2000000000000
# Ag-108m                 20000000000000   700000000000   700000000000
#
#              Transport Security Threshold [Bq]  \
# Radionuclide
# Ac-225                          18000000000000
# Ac-227                     270000000000.000031
# Ac-228                        1500000000000000
# Ag-105                        6000000000000000
# Ag-108m                       2100000000000000
#
#              High Activity Source Directive 2013/59/EURATOM  [Bq]  \
# Radionuclide
# Ac-225                                              90000000000
# Ac-227                                              40000000000
# Ac-228                                              30000000000
# Ag-105                                             100000000000
# Ag-108m                                             40000000000
#
#               Activity concentration for exempt material (Bq/g)  \
# Radionuclide
# Ac-225                                                     10.0
# Ac-227                                                      0.1
# Ac-228                                                     10.0
# Ag-105                                                    100.0
# Ag-108m                                                    10.0
#
#               Activity limit for an exempt consignment (Bq) P1  \
# Radionuclide
# Ac-225                                                   10000
# Ac-227                                                    1000
# Ac-228                                                 1000000
# Ag-105                                                 1000000
# Ag-108m                                                1000000
#
#               Desintegration [Years]
# Radionuclide
# Ac-225                      0.027379
# Ac-227                           NaN
# Ac-228                      0.000719
# Ag-105                           NaN
# Ag-108m                          NaN

# %% [markdown]
# # Input

# %%
isotope_1 = "Cs-137"
activity_1 = 9
activity_1 = activity_1 / 1000000

isotope_2 = "Am-241"
activity_2 = 300
activity_2 = activity_2 / 1000000

isotope_3 = "Sr-90"
activity_3 = 8
activity_3 = activity_3 / 1000000

mass_kg = 10

activity_list = [activity_1, activity_2, activity_3 ]
selected_isotopes = df.loc[[isotope_1, isotope_2, isotope_3]]
selected_isotopes
# Out:
#              D-Value [TBq] D1-Value (encapsulated) [TBq]  \
# Radionuclide
# Cs-137                 0.1                           0.1
# Am-241                0.06                             8
# Sr-90                    1                             4
#
#              D2-Value (dispersed) [TBq] A1 [TBq] A2 [TBq]  \
# Radionuclide
# Cs-137                               20        2      0.6
# Am-241                             0.06       10    0.001
# Sr-90                                 1      0.3      0.3
#
#              Transport Security Threshold [TBq]  Unnamed: 7  \
# Radionuclide
# Cs-137                                        1  10*D-Value
# Am-241                                      0.6  10*D-Value
# Sr-90                                        10  10*D-Value
#
#              High Activity Source Directive 2013/59/EURATOM  [TBq]  \
# Radionuclide
# Cs-137                                                      0.1
# Am-241                                                     0.06
# Sr-90                                                         1
#
#              D-Value [Bq] P2 D1-Value (encapsulated) [Bq]  \
# Radionuclide
# Cs-137          100000000000                 100000000000
# Am-241           60000000000                8000000000000
# Sr-90          1000000000000                4000000000000
#
#              D2-Value (dispersed) [Bq]         A1 [Bq]       A2 [Bq]  \
# Radionuclide
# Cs-137                  20000000000000   2000000000000  600000000000
# Am-241                     60000000000  10000000000000    1000000000
# Sr-90                    1000000000000    300000000000  300000000000
#
#              Transport Security Threshold [Bq]  \
# Radionuclide
# Cs-137                           1000000000000
# Am-241                            600000000000
# Sr-90                           10000000000000
#
#              High Activity Source Directive 2013/59/EURATOM  [Bq]  \
# Radionuclide
# Cs-137                                             100000000000
# Am-241                                              60000000000
# Sr-90                                             1000000000000
#
#               Activity concentration for exempt material (Bq/g)  \
# Radionuclide
# Cs-137                                                     10.0
# Am-241                                                      1.0
# Sr-90                                                     100.0
#
#               Activity limit for an exempt consignment (Bq) P1  \
# Radionuclide
# Cs-137                                                   10000
# Am-241                                                   10000
# Sr-90                                                    10000
#
#               Desintegration [Years]
# Radionuclide
# Cs-137                         30.16
# Am-241                        432.00
# Sr-90                          29.10

# %% [markdown]
# # Process data

# %%
# Add columns with activity, activity ratio, multiple A1 and multiple A2
selected_isotopes ["Activity [TBq]"] = activity_list
selected_isotopes ["Isotope Activity Ratio"] = selected_isotopes ["Activity [TBq]"] /selected_isotopes ["Activity [TBq]"].sum()

selected_isotopes ["Isotope A1 Ratio"] = selected_isotopes ["Activity [TBq]"] /selected_isotopes ["Activity [TBq]"].sum() / selected_isotopes ["A1 [TBq]"]
selected_isotopes ["Isotope A2 Ratio"] = selected_isotopes ["Activity [TBq]"] /selected_isotopes ["Activity [TBq]"].sum() / selected_isotopes ["A2 [TBq]"]
selected_isotopes ["Isotope xxxxx"] = selected_isotopes ["Activity [TBq]"] /selected_isotopes ["Isotope A1 Ratio"]      

selected_isotopes ["Multiple A1"] = selected_isotopes ["Activity [TBq]"] / selected_isotopes ["A1 [TBq]"]
selected_isotopes ["Multiple A2"] = selected_isotopes ["Activity [TBq]"] / selected_isotopes ["A2 [TBq]"]

# Calculate sum of multiple A1
sum_A1 = selected_isotopes ["Multiple A1"].sum()
sum_Isotope_A1_ratio = selected_isotopes["Isotope A1 Ratio"].sum()

# Calculate sum of multiple A2
sum_A2 = selected_isotopes ["Multiple A2"].sum()
sum_Isotope_A2_ratio = selected_isotopes["Isotope A2 Ratio"].sum()

# Add column for LSA-1, LSA-2, Type-A Package
selected_isotopes ["Activity concentration in consignment (Bq/g)"] = selected_isotopes ["Activity [TBq]"] * 1000000000 / mass_kg
selected_isotopes["Average specific activty"] = selected_isotopes ["Activity concentration in consignment (Bq/g)"] / selected_isotopes ["Activity concentration for exempt material (Bq/g)"]
# selected_isotopes["LSA-2"] = selected_isotopes ["Activity concentration in consignment (Bq/g)"] / selected_isotopes["A2 [TBq]"] / 100000000
selected_isotopes["Type-A Package"] =  selected_isotopes ["Activity [TBq]"] / selected_isotopes ["A1 [TBq]"]

# Calculate sums
average_activity_sum = selected_isotopes["Average specific activty"].sum()
# lsa_2_sum = selected_isotopes["LSA-2"].sum()
type_A_sum = selected_isotopes["Type-A Package"].sum()
act_concent_in_package_sum = selected_isotopes ["Activity concentration in consignment (Bq/g)"].sum()

selected_isotopes
# Out:
#              D-Value [TBq] D1-Value (encapsulated) [TBq]  \
# Radionuclide
# Cs-137                 0.1                           0.1
# Am-241                0.06                             8
# Sr-90                    1                             4
#
#              D2-Value (dispersed) [TBq] A1 [TBq] A2 [TBq]  \
# Radionuclide
# Cs-137                               20        2      0.6
# Am-241                             0.06       10    0.001
# Sr-90                                 1      0.3      0.3
#
#              Transport Security Threshold [TBq]  Unnamed: 7  \
# Radionuclide
# Cs-137                                        1  10*D-Value
# Am-241                                      0.6  10*D-Value
# Sr-90                                        10  10*D-Value
#
#              High Activity Source Directive 2013/59/EURATOM  [TBq]  \
# Radionuclide
# Cs-137                                                      0.1
# Am-241                                                     0.06
# Sr-90                                                         1
#
#              D-Value [Bq] P2 D1-Value (encapsulated) [Bq]  ... Activity [TBq]  \
# Radionuclide                                               ...
# Cs-137          100000000000                 100000000000  ...       0.000009
# Am-241           60000000000                8000000000000  ...       0.000300
# Sr-90          1000000000000                4000000000000  ...       0.000008
#
#              Isotope Activity Ratio Isotope A1 Ratio Isotope A2 Ratio  \
# Radionuclide
# Cs-137                     0.028391         0.014196         0.047319
# Am-241                     0.946372         0.094637        946.37224
# Sr-90                      0.025237         0.084122         0.084122
#
#              Isotope xxxxx  Multiple A1  Multiple A2  \
# Radionuclide
# Cs-137            0.000634     0.000005     0.000015
# Am-241             0.00317      0.00003          0.3
# Sr-90             0.000095     0.000027     0.000027
#
#               Activity concentration in consignment (Bq/g)  \
# Radionuclide
# Cs-137                                               900.0
# Am-241                                             30000.0
# Sr-90                                                800.0
#
#               Average specific activty  Type-A Package
# Radionuclide
# Cs-137                            90.0        0.000005
# Am-241                         30000.0         0.00003
# Sr-90                              8.0        0.000027
#
# [3 rows x 28 columns]

# %%
selected_isotopes["Isotope A2 Ratio"]
# Out:
# Radionuclide
# Cs-137     0.047319
# Am-241    946.37224
# Sr-90      0.084122
# Name: Isotope A2 Ratio, dtype: object

# %% [markdown]
# # Set category

# %%
category_lsa = ''
#Wart A2 dla mieszaniny


if average_activity_sum  <= 30:
   category_lsa = "LSA-I"
else :
    a2_ratio = 1/sum_Isotope_A2_ratio
    specific_activity_mass = a2_ratio / mass_kg / 1000
    print(specific_activity_mass)
    if specific_activity_mass <= 0.0001:
        category_lsa = "LSA-II"
    elif specific_activity_mass <= 0.002:
        category_lsa = "LSA-III"
    else:
        category_lsa = "NOT LSA"

category_lsa
# Out:
# 1.0565199277878071e-07
# 'LSA-II'

# %% [markdown]
# # Printing

# %%
# Multiple A1, A2
print("Multiple A1: ", sum_A1)
print("Multiple A2: ", sum_A2)

print("sum_Isotope_A1_ratio: ", sum_Isotope_A1_ratio)
print("Wart A1 dla mieszaniny ", 1/sum_Isotope_A1_ratio)

print("sum_Isotope_A2_ratio: ", sum_Isotope_A2_ratio)
print("Wart A2 dla mieszaniny ", 1/sum_Isotope_A2_ratio)

# exempted material
if sum_A2  <= 0.001:
    print("Exempted material (", selected_isotopes ["Multiple A2"].sum(), ")")
else:
    print("NOT Exempted material (", selected_isotopes ["Multiple A2"].sum(), ")")

# exempted special form
if sum_A1  <= 0.001:
    print("Exempted special form(", selected_isotopes ["Multiple A1"].sum(), ")")
else:
    print("NOT Exempted special form (", selected_isotopes ["Multiple A1"].sum(), ")")

# exempted liquid
if sum_A2  <= 0.0001:
    print("Exempted liquid(", selected_isotopes ["Multiple A2"].sum(), ")")
else:
    print("NOT Exempted liquid (", selected_isotopes ["Multiple A2"].sum(), ")")


# Type-A Package
if type_A_sum <= 1:
    print("TYPE-A (", type_A_sum, ")")
else:
    print("NOT TYPE-A (", type_A_sum, ")")

# # Print table
# print("")
# print("")
selected_isotopes[["Isotope Activity Ratio", "Multiple A1", "Multiple A2", "Type-A Package"]]
# Out:
# Multiple A1:  6.116666666666667e-05
# Multiple A2:  0.30004166666666665
# sum_Isotope_A1_ratio:  0.1929547844374343
# Wart A1 dla mieszaniny  5.182561307901906
# sum_Isotope_A2_ratio:  946.503680336488
# Wart A2 dla mieszaniny  0.0010565199277878072
# NOT Exempted material ( 0.30004166666666665 )
# Exempted special form( 6.116666666666667e-05 )
# NOT Exempted liquid ( 0.30004166666666665 )
# TYPE-A ( 6.116666666666667e-05 )
#               Isotope Activity Ratio Multiple A1 Multiple A2 Type-A Package
# Radionuclide
# Cs-137                      0.028391    0.000005    0.000015       0.000005
# Am-241                      0.946372     0.00003         0.3        0.00003
# Sr-90                       0.025237    0.000027    0.000027       0.000027
